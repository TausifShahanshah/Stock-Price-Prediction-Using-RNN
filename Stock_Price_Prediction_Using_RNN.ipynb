# %% [markdown]
# <a href="https://colab.research.google.com/github/TausifShahanshah/Stock-Price-Prediction-Using-RNN/blob/main/Stock_Price_Prediction_Using_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a id="1"></a>
# ## 1.Loading Data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Stock Price Prediction/TSLA.csv")

# %%
data.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
data.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416 entries, 0 to 2415
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2416 non-null   object
#  1   Open       2416 non-null   float64
#  2   High       2416 non-null   float64
#  3   Low        2416 non-null   float64
#  4   Close      2416 non-null   float64
#  5   Adj Close  2416 non-null   float64
#  6   Volume     2416 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 132.2+ KB

# %% [markdown]
# <a id="2"></a>
# ## 2.Spliting Data as Train and Validation

# %%
length_data = len(data)     # rows that data has
split_ratio = 0.7           # %70 train + %30 validation
length_train = round(length_data * split_ratio)
length_validation = length_data - length_train
print("Data length :", length_data)
print("Train data length :", length_train)
print("Validation data lenth :", length_validation)
# Out:
# Data length : 2416
# Train data length : 1691
# Validation data lenth : 725

# %%
train_data = data[:length_train].iloc[:,:2]
train_data['Date'] = pd.to_datetime(train_data['Date'])  # converting to date time object
train_data
# Out:
#            Date        Open
# 0    2010-06-29   19.000000
# 1    2010-06-30   25.790001
# 2    2010-07-01   25.000000
# 3    2010-07-02   23.000000
# 4    2010-07-06   20.000000
# ...         ...         ...
# 1686 2017-03-10  246.210007
# 1687 2017-03-13  244.820007
# 1688 2017-03-14  246.110001
# 1689 2017-03-15  257.000000
# 1690 2017-03-16  262.399994
#
# [1691 rows x 2 columns]

# %%
validation_data = data[length_train:].iloc[:,:2]
validation_data['Date'] = pd.to_datetime(validation_data['Date'])  # converting to date time object
validation_data
# Out:
#            Date        Open
# 1691 2017-03-17  264.000000
# 1692 2017-03-20  260.600006
# 1693 2017-03-21  262.829987
# 1694 2017-03-22  251.559998
# 1695 2017-03-23  255.389999
# ...         ...         ...
# 2411 2020-01-28  568.489990
# 2412 2020-01-29  575.690002
# 2413 2020-01-30  632.419983
# 2414 2020-01-31  640.000000
# 2415 2020-02-03  673.690002
#
# [725 rows x 2 columns]

# %% [markdown]
# <a id="3"></a>
# ## 3.Creating Train Dataset from Train split

# %%
# We will get Open column as our dataset
# Dataset to be converted to array by adding .values
dataset_train = train_data.Open.values
dataset_train.shape
# Out:
# (1691,)

# %%
# Change 1d array to 2d array
# Changing shape from (2415,) to (2415,1)
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (1691, 1)

# %% [markdown]
# #### <a id="4"></a>
# ## 4.Normalization / Feature Scaling

# %% [markdown]
# * Dataset values will be in between 0 and 1 after scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))


# scaling dataset
dataset_train_scaled = scaler.fit_transform(dataset_train)

dataset_train_scaled.shape
# Out:
# (1691, 1)

# %%
plt.subplots(figsize = (15,6))
plt.plot(dataset_train_scaled)
plt.xlabel("Days as 1st, 2nd, 3rd..")
plt.ylabel("Open Price")
plt.show()

# %% [markdown]
# <a id="5"></a>
# ## 5.Creating X_train and y_train from Train data

# %% [markdown]
# * We have train data composed of stock open prices over days
# * So, it has 1691 prices corresponding 1691 days
# * My aim is to predict the open price of the next day.
# * I can use a time step of 50 days.
# * I will pick first 50 open prices (0 to 50), 1st 50 price will be in X_train data
# * Then predict the price of 51th day; and 51th price will be in y_train data
# * Again, i will pick prices from 1 to 51, those will be in X_train data
# * Then predict the next days price, 52nd price will be in y_train data

# %%
X_train = []
y_train = []

time_step = 50

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0])
    y_train.append(dataset_train_scaled[i,0])

# convert list to array
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print("Shape of X_train before reshape :",X_train.shape)
print("Shape of y_train before reshape :",y_train.shape)
# Out:
# Shape of X_train before reshape : (1641, 50)
# Shape of y_train before reshape : (1641,)

# %% [markdown]
# ## Reshape

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape :",X_train.shape)
print("Shape of y_train after reshape :",y_train.shape)
# Out:
# Shape of X_train after reshape : (1641, 50, 1)
# Shape of y_train after reshape : (1641, 1)

# %%
# Shape of X_train : 1641 x 50 x 1
# That means we have 1641 rows, each row has 50 rows and 1 column
# Lets check the first row: it has 50 rows (open prices of 49 days)

X_train[0]
# Out:
# array([[0.01053291],
#        [0.03553936],
#        [0.03262991],
#        [0.02526425],
#        [0.01421574],
#        [0.00095754],
#        [0.        ],
#        [0.00530328],
#        [0.00666594],
#        [0.00460354],
#        [0.00662911],
#        [0.01399478],
#        [0.01679373],
#        [0.01926123],
#        [0.02102899],
#        [0.01664641],
#        [0.01605716],
#        [0.01859832],
#        [0.01973999],
#        [0.01756712],
#        [0.0162413 ],
#        [0.01705153],
#        [0.01495231],
#        [0.01605716],
#        [0.01789858],
#        [0.02139727],
#        [0.01988731],
#        [0.01458403],
#        [0.01384746],
#        [0.01292675],
#        [0.00939123],
#        [0.0061135 ],
#        [0.00751299],
#        [0.00850735],
#        [0.01038559],
#        [0.01270578],
#        [0.00883881],
#        [0.00924392],
#        [0.01086436],
#        [0.01145362],
#        [0.01112216],
#        [0.01381063],
#        [0.01329503],
#        [0.0131109 ],
#        [0.01296358],
#        [0.01281627],
#        [0.0155784 ],
#        [0.01741981],
#        [0.01646228],
#        [0.01664641]])

# %%
# Check the first item in y_train
# It is the price of 50th day

y_train[0]
# Out:
# array([0.01789858])

# %% [markdown]
# <a id="6"></a>
# ## 6.Creating RNN model

# %%
# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout
from keras.metrics import MeanAbsoluteError

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True,
              input_shape = (X_train.shape[1],1))
             )

regressor.add(
    Dropout(0.2)
             )


# adding second RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding third RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding fourth RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50)
             )

regressor.add(
    Dropout(0.2)
             )

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(
    optimizer = "adam",
    loss = "mean_squared_error",
    metrics = [MeanAbsoluteError()])

# fitting the RNN
history = regressor.fit(X_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 52/52 [==============================] - 17s 230ms/step - loss: 0.3179 - mean_absolute_error: 0.4414
# Epoch 2/50
# 52/52 [==============================] - 11s 212ms/step - loss: 0.1525 - mean_absolute_error: 0.3017
# Epoch 3/50
# 52/52 [==============================] - 10s 196ms/step - loss: 0.0979 - mean_absolute_error: 0.2440
# Epoch 4/50
# 52/52 [==============================] - 12s 236ms/step - loss: 0.0817 - mean_absolute_error: 0.2141
# Epoch 5/50
# 52/52 [==============================] - 12s 231ms/step - loss: 0.0528 - mean_absolute_error: 0.1711
# Epoch 6/50
# 52/52 [==============================] - 14s 269ms/step - loss: 0.0423 - mean_absolute_error: 0.1502
# Epoch 7/50
# 52/52 [==============================] - 12s 229ms/step - loss: 0.0408 - mean_absolute_error: 0.1456
# Epoch 8/50
# 52/52 [==============================] - 12s 230ms/step - loss: 0.0320 - mean_absolute_error: 0.1275
# Epoch 9/50
# 52/52 [==============================] - 10s 193ms/step - loss: 0.0274 - mean_absolute_error: 0.1177
# Epoch 10/50
# 52/52 [==============================] - 12s 231ms/step - loss: 0.0234 - mean_absolute_error: 0.1057
# Epoch 11/50
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0212 - mean_absolute_error: 0.1014
# Epoch 12/50
# 52/52 [==============================] - 12s 234ms/step - loss: 0.0208 - mean_absolute_error: 0.1003
# Epoch 13/50
# 52/52 [==============================] - 14s 269ms/step - loss: 0.0179 - mean_absolute_error: 0.0936
# Epoch 14/50
# 52/52 [==============================] - 15s 288ms/step - loss: 0.0158 - mean_absolute_error: 0.0863
# Epoch 15/50
# 52/52 [==============================] - 12s 232ms/step - loss: 0.0150 - mean_absolute_error: 0.0848
# Epoch 16/50
# 52/52 [==============================] - 11s 220ms/step - loss: 0.0137 - mean_absolute_error: 0.0825
# Epoch 17/50
# 52/52 [==============================] - 10s 192ms/step - loss: 0.0113 - mean_absolute_error: 0.0734
# Epoch 18/50
# 52/52 [==============================] - 12s 231ms/step - loss: 0.0119 - mean_absolute_error: 0.0760
# Epoch 19/50
# 52/52 [==============================] - 12s 231ms/step - loss: 0.0103 - mean_absolute_error: 0.0696
# Epoch 20/50
# 52/52 [==============================] - 12s 230ms/step - loss: 0.0109 - mean_absolute_error: 0.0708
# Epoch 21/50
# 52/52 [==============================] - 12s 233ms/step - loss: 0.0089 - mean_absolute_error: 0.0651
# Epoch 22/50
# 52/52 [==============================] - 10s 186ms/step - loss: 0.0093 - mean_absolute_error: 0.0667
# Epoch 23/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0094 - mean_absolute_error: 0.0680
# Epoch 24/50
# 52/52 [==============================] - 12s 233ms/step - loss: 0.0082 - mean_absolute_error: 0.0633
# Epoch 25/50
# 52/52 [==============================] - 12s 231ms/step - loss: 0.0073 - mean_absolute_error: 0.0597
# Epoch 26/50
# 52/52 [==============================] - 12s 234ms/step - loss: 0.0064 - mean_absolute_error: 0.0566
# Epoch 27/50
# 52/52 [==============================] - 11s 214ms/step - loss: 0.0067 - mean_absolute_error: 0.0564
# Epoch 28/50
# 52/52 [==============================] - 11s 204ms/step - loss: 0.0065 - mean_absolute_error: 0.0561
# Epoch 29/50
# 52/52 [==============================] - 14s 274ms/step - loss: 0.0065 - mean_absolute_error: 0.0553
# Epoch 30/50
# 52/52 [==============================] - 12s 239ms/step - loss: 0.0059 - mean_absolute_error: 0.0541
# Epoch 31/50
# 52/52 [==============================] - 12s 230ms/step - loss: 0.0058 - mean_absolute_error: 0.0541
# Epoch 32/50
# 52/52 [==============================] - 12s 230ms/step - loss: 0.0062 - mean_absolute_error: 0.0545
# Epoch 33/50
# 52/52 [==============================] - 12s 231ms/step - loss: 0.0057 - mean_absolute_error: 0.0533
# Epoch 34/50
# 52/52 [==============================] - 10s 199ms/step - loss: 0.0050 - mean_absolute_error: 0.0497
# Epoch 35/50
# 52/52 [==============================] - 11s 217ms/step - loss: 0.0047 - mean_absolute_error: 0.0482
# Epoch 36/50
# 52/52 [==============================] - 12s 232ms/step - loss: 0.0048 - mean_absolute_error: 0.0492
# Epoch 37/50
# 52/52 [==============================] - 12s 229ms/step - loss: 0.0049 - mean_absolute_error: 0.0493
# Epoch 38/50
# 52/52 [==============================] - 12s 233ms/step - loss: 0.0045 - mean_absolute_error: 0.0474
# Epoch 39/50
# 52/52 [==============================] - 11s 205ms/step - loss: 0.0044 - mean_absolute_error: 0.0460
# Epoch 40/50
# 52/52 [==============================] - 11s 203ms/step - loss: 0.0042 - mean_absolute_error: 0.0466
# Epoch 41/50
# 52/52 [==============================] - 12s 233ms/step - loss: 0.0045 - mean_absolute_error: 0.0470
# Epoch 42/50
# 52/52 [==============================] - 12s 239ms/step - loss: 0.0040 - mean_absolute_error: 0.0448
# Epoch 43/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0037 - mean_absolute_error: 0.0435
# Epoch 44/50
# 52/52 [==============================] - 12s 234ms/step - loss: 0.0035 - mean_absolute_error: 0.0427
# Epoch 45/50
# 52/52 [==============================] - 9s 178ms/step - loss: 0.0038 - mean_absolute_error: 0.0437
# Epoch 46/50
# 52/52 [==============================] - 13s 257ms/step - loss: 0.0036 - mean_absolute_error: 0.0424
# Epoch 47/50
# 52/52 [==============================] - 12s 234ms/step - loss: 0.0035 - mean_absolute_error: 0.0421
# Epoch 48/50
# 52/52 [==============================] - 11s 217ms/step - loss: 0.0035 - mean_absolute_error: 0.0419
# Epoch 49/50
# 52/52 [==============================] - 12s 230ms/step - loss: 0.0044 - mean_absolute_error: 0.0470
# Epoch 50/50
# 52/52 [==============================] - 11s 210ms/step - loss: 0.0034 - mean_absolute_error: 0.0415

# %% [markdown]
# <a id="7"></a>
# ## 7.Evaluating Model

# %%
# Losses
history.history["loss"]
# Out:
# [0.31791290640830994,
#  0.15253183245658875,
#  0.0979444831609726,
#  0.08168336749076843,
#  0.05276909098029137,
#  0.042322590947151184,
#  0.040756579488515854,
#  0.032001737505197525,
#  0.027427442371845245,
#  0.023403260856866837,
#  0.02117932215332985,
#  0.02079198509454727,
#  0.01787654124200344,
#  0.015813911333680153,
#  0.015023819170892239,
#  0.013725505210459232,
#  0.011258423328399658,
#  0.01186240091919899,
#  0.010270712897181511,
#  0.010946294292807579,
#  0.00888849701732397,
#  0.009302450343966484,
#  0.009432347491383553,
#  0.008157329633831978,
#  0.007256899960339069,
#  0.006401760969310999,
#  0.006653663702309132,
#  0.006496497429907322,
#  0.006460638251155615,
#  0.005922684911638498,
#  0.005835423711687326,
#  0.006196331232786179,
#  0.005725956056267023,
#  0.00504927197471261,
#  0.004701266530901194,
#  0.004830452147871256,
#  0.004850585944950581,
#  0.0044829342514276505,
#  0.004358652047812939,
#  0.004238431341946125,
#  0.0045492020435631275,
#  0.003951853606849909,
#  0.0037497845478355885,
#  0.0035181879065930843,
#  0.0037834167014807463,
#  0.003618912072852254,
#  0.003493022173643112,
#  0.003505818312987685,
#  0.0044160690158605576,
#  0.0033669807016849518]

# %%
# Plotting Loss vs Epochs
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show()

# %%
# Plotting MeanAbsoluteError vs Epochs
plt.figure(figsize =(10,5))
plt.plot(history.history["mean_absolute_error"])
plt.xlabel("Epochs")
plt.ylabel("Mean Absolute Error")
plt.title("Simple RNN model, Mean Absolute Error vs Epoch")
plt.show()

# %% [markdown]
# ## Model predictions for train data

# %%
y_pred = regressor.predict(X_train)  # predictions
y_pred = scaler.inverse_transform(y_pred) # scaling back from 0-1 to original
y_pred.shape
# Out:
# 52/52 [==============================] - 2s 20ms/step
# (1641, 1)

# %%
y_train = scaler.inverse_transform(y_train) # scaling back from 0-1 to original
y_train.shape
# Out:
# (1641, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred, color = "b", label = "y_pred" )
plt.plot(y_train, color = "g", label = "y_train")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Predictions with input X_train vs y_train")
plt.legend()
plt.show()

# %% [markdown]
# <a id="8"></a>
# ## 8.Creating Test Dataset from Validation Data

# %% [markdown]
# ### Converting array and scaling

# %%
dataset_validation = validation_data.Open.values  # getting "open" column and converting to array
dataset_validation = np.reshape(dataset_validation, (-1,1))  # converting 1D to 2D array
scaled_dataset_validation =  scaler.fit_transform(dataset_validation)  # scaling open values to between 0 and 1
print("Shape of scaled validation dataset :",scaled_dataset_validation.shape)
# Out:
# Shape of scaled validation dataset : (725, 1)

# %% [markdown]
# ### Creating X_test and y_test

# %%
# Creating X_test and y_test
X_test = []
y_test = []

for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i,0])
    y_test.append(scaled_dataset_validation[i,0])

# %% [markdown]
# ### Converting to array

# %%
# Converting to array
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Shape of X_test before reshape :",X_test.shape)
print("Shape of y_test before reshape :",y_test.shape)
# Out:
# Shape of X_test before reshape : (675, 50)
# Shape of y_test before reshape : (675,)

# %% [markdown]
# ### Reshape

# %%
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))  # reshape to 3D array
y_test = np.reshape(y_test, (-1,1))  # reshape to 2D array

# %%
print("Shape of X_test after reshape :",X_test.shape)
print("Shape of y_test after reshape :",y_test.shape)
# Out:
# Shape of X_test after reshape : (675, 50, 1)
# Shape of y_test after reshape : (675, 1)

# %% [markdown]
# <a id="9"></a>
# ## 9.Evaluating with Validation Data

# %%
# predictions with X_test data
y_pred_of_test = regressor.predict(X_test)
# scaling back from 0-1 to original
y_pred_of_test = scaler.inverse_transform(y_pred_of_test)
print("Shape of y_pred_of_test :",y_pred_of_test.shape)
# Out:
# 22/22 [==============================] - 0s 18ms/step
# Shape of y_pred_of_test : (675, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred_of_test, label = "y_pred_of_test", c = "orange")
plt.plot(scaler.inverse_transform(y_test), label = "y_test", c = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Prediction with input X_test vs y_test")
plt.legend()
plt.show()

# %%
# Visualisation
plt.subplots(figsize =(30,12))
plt.plot(train_data.Date, train_data.Open, label = "train_data", color = "b")
plt.plot(validation_data.Date, validation_data.Open, label = "validation_data", color = "g")
plt.plot(train_data.Date.iloc[time_step:], y_pred, label = "y_pred", color = "r")
plt.plot(validation_data.Date.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Train-Validation-Prediction")
plt.legend()
plt.show()

# %% [markdown]
# <a id="10"></a>
# ## 10.Creating LSTM Model

# %%
y_train = scaler.fit_transform(y_train)

# %%
from keras.layers import LSTM

model_lstm = Sequential()
model_lstm.add(
    LSTM(64,return_sequences=True,input_shape = (X_train.shape[1],1))) #64 lstm neuron block
model_lstm.add(
    LSTM(64, return_sequences= False))
model_lstm.add(Dense(32))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error", optimizer = "adam", metrics = [MeanAbsoluteError()])
history2 = model_lstm.fit(X_train, y_train, epochs = 10, batch_size = 10)
# Out:
# Epoch 1/10
# 165/165 [==============================] - 7s 12ms/step - loss: 0.0067 - mean_absolute_error: 0.0447
# Epoch 2/10
# 165/165 [==============================] - 2s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0265
# Epoch 3/10
# 165/165 [==============================] - 1s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0233
# Epoch 4/10
# 165/165 [==============================] - 1s 8ms/step - loss: 0.0010 - mean_absolute_error: 0.0221
# Epoch 5/10
# 165/165 [==============================] - 1s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0237
# Epoch 6/10
# 165/165 [==============================] - 1s 8ms/step - loss: 8.2066e-04 - mean_absolute_error: 0.0190
# Epoch 7/10
# 165/165 [==============================] - 1s 8ms/step - loss: 7.6837e-04 - mean_absolute_error: 0.0188
# Epoch 8/10
# 165/165 [==============================] - 1s 8ms/step - loss: 7.6766e-04 - mean_absolute_error: 0.0182
# Epoch 9/10
# 165/165 [==============================] - 1s 8ms/step - loss: 6.0395e-04 - mean_absolute_error: 0.0164
# Epoch 10/10
# 165/165 [==============================] - 2s 10ms/step - loss: 5.5691e-04 - mean_absolute_error: 0.0155

# %% [markdown]
# <a id="11"></a>
# ## 11.Evaluating LSTM Model

# %%
plt.figure(figsize =(10,5))
plt.plot(history2.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("LSTM model, Loss vs Epoch")
plt.show()

# %%
plt.subplots(figsize =(30,12))
plt.plot(scaler.inverse_transform(model_lstm.predict(X_test)), label = "y_pred_of_test", c = "orange" )
plt.plot(scaler.inverse_transform(y_test), label = "y_test", color = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("LSTM model, Predictions with input X_test vs y_test")
plt.legend()
plt.show()
# Out:
# 22/22 [==============================] - 1s 4ms/step

# %% [markdown]
# <a id="12"></a>
# ## 12.Future price prediction

# %% [markdown]
# * Which day is the last day in our data?

# %%
data.iloc[-1]
# Out:
# Date         2020-02-03
# Open         673.690002
# High         786.140015
# Low           673.52002
# Close             780.0
# Adj Close         780.0
# Volume         47065000
# Name: 2415, dtype: object

# %% [markdown]
# * We can predict the open price for the day after 03/02/2020--> for  04/02/2020.
# * We will use last 50 days Open price as input of our model for this prediction
# * Let us prepare it:

# %%
X_input = data.iloc[-time_step:].Open.values               # getting last 50 rows and converting to array
X_input = scaler.fit_transform(X_input.reshape(-1,1))      # converting to 2D array and scaling
X_input = np.reshape(X_input, (1,50,1))                    # reshaping : converting to 3D array
print("Shape of X_input :", X_input.shape)
X_input
# Out:
# Shape of X_input : (1, 50, 1)
# array([[[0.08887858],
#         [0.07293275],
#         [0.03125275],
#         [0.0433356 ],
#         [0.01704957],
#         [0.00499579],
#         [0.00496672],
#         [0.        ],
#         [0.00935258],
#         [0.02425283],
#         [0.00996251],
#         [0.01626537],
#         [0.02088356],
#         [0.03067181],
#         [0.06529382],
#         [0.07412361],
#         [0.0919283 ],
#         [0.09628509],
#         [0.14403554],
#         [0.14879901],
#         [0.19727559],
#         [0.23494732],
#         [0.23927504],
#         [0.25838679],
#         [0.28612509],
#         [0.30671818],
#         [0.28868109],
#         [0.21958234],
#         [0.27622064],
#         [0.32269309],
#         [0.32260596],
#         [0.38339771],
#         [0.41912346],
#         [0.4870894 ],
#         [0.44262108],
#         [0.47663308],
#         [0.62406695],
#         [0.58195129],
#         [0.47735921],
#         [0.51761593],
#         [0.58337448],
#         [0.70431908],
#         [0.68212844],
#         [0.70065934],
#         [0.61747362],
#         [0.69444361],
#         [0.71535625],
#         [0.88013007],
#         [0.90214644],
#         [1.        ]]])

# %%
simple_RNN_prediction = scaler.inverse_transform(regressor.predict(X_input))
LSTM_prediction = scaler.inverse_transform(model_lstm.predict(X_input))
print("Simple RNN, Open price prediction for 2/04/2020      :", simple_RNN_prediction[0,0])
print("LSTM prediction, Open price prediction for 2/04/2020 :", LSTM_prediction[0,0])
# Out:
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 35ms/step
# Simple RNN, Open price prediction for 2/04/2020      : 633.9674
# LSTM prediction, Open price prediction for 2/04/2020 : 654.31085
